# %%
def build_model(input_shape, num_classes):
    model = Sequential([
        #  Rescaling : to bring values between [0,1]
        Rescaling(1./255, input_shape=input_shape),
        Conv2D(32, 3, padding='same', activation='relu'),
        MaxPooling2D(),
        Conv2D(64, 3, padding='same', activation='relu'),
        MaxPooling2D(),
        Dropout(0.2),
        Conv2D(64, 3, padding='same', activation='relu'),
        MaxPooling2D(),
        Dropout(0.22),
        Conv2D(128, 3, padding='same', activation='relu'),
        MaxPooling2D(),
        Dropout(0.2),
        Conv2D(256, 3, activation='relu'),
        MaxPooling2D(),
        Dropout(0.2),
        Conv2D(128, 3, activation='relu'),
        MaxPooling2D(),
        Dropout(0.2),
        Flatten(),
        Dense(128, activation='relu'),
        Dense(num_classes)
    ])
    return model


model = build_model(input_shape=input_shape, num_classes=len(class_names))

# %% [markdown]
#  #### **Todo:** Compile your model (Choose optimizer and loss function appropriately)

# %%
model = complie_model(model)
display(model.summary())
# Out:
# Model: "sequential_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# rescaling_6 (Rescaling)      (None, 180, 180, 3)       0
# _________________________________________________________________
# conv2d_24 (Conv2D)           (None, 180, 180, 32)      896
# _________________________________________________________________
# max_pooling2d_24 (MaxPooling (None, 90, 90, 32)        0
# _________________________________________________________________
# conv2d_25 (Conv2D)           (None, 90, 90, 64)        18496
# _________________________________________________________________
# max_pooling2d_25 (MaxPooling (None, 45, 45, 64)        0
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 45, 45, 64)        0
# _________________________________________________________________
# conv2d_26 (Conv2D)           (None, 45, 45, 64)        36928
# _________________________________________________________________
# max_pooling2d_26 (MaxPooling (None, 22, 22, 64)        0
# _________________________________________________________________
# dropout_13 (Dropout)         (None, 22, 22, 64)        0
# _________________________________________________________________
# conv2d_27 (Conv2D)           (None, 22, 22, 128)       73856
# _________________________________________________________________
# max_pooling2d_27 (MaxPooling (None, 11, 11, 128)       0
# _________________________________________________________________
# dropout_14 (Dropout)         (None, 11, 11, 128)       0
# _________________________________________________________________
# conv2d_28 (Conv2D)           (None, 9, 9, 256)         295168
# _________________________________________________________________
# max_pooling2d_28 (MaxPooling (None, 4, 4, 256)         0
# _________________________________________________________________
# dropout_15 (Dropout)         (None, 4, 4, 256)         0
# _________________________________________________________________
# conv2d_29 (Conv2D)           (None, 2, 2, 128)         295040
# _________________________________________________________________
# max_pooling2d_29 (MaxPooling (None, 1, 1, 128)         0
# _________________________________________________________________
# dropout_16 (Dropout)         (None, 1, 1, 128)         0
# _________________________________________________________________
# flatten_6 (Flatten)          (None, 128)               0
# _________________________________________________________________
# dense_12 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dense_13 (Dense)             (None, 9)                 1161
# =================================================================
# Total params: 738,057
# Trainable params: 738,057
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
#  #### **Todo:**  Train your model

# %%
epochs = 70
# Your code goes here, use 50 epochs.
callbacks = [
    tf.keras.callbacks.EarlyStopping(patience=5),
    tf.keras.callbacks.ModelCheckpoint(filepath='model.{epoch:02d}-{val_loss:.2f}.h5')
]
# history = train_model(model, train_ds, val_ds, epochs, callbacks=callbacks)
history = train_model(model, train_ds, val_ds, epochs)
# Out:
# Epoch 1/70
# 169/169 [==============================] - 82s 461ms/step - loss: 2.1722 - accuracy: 0.1629 - val_loss: 1.9904 - val_accuracy: 0.2301
# Epoch 2/70
# 169/169 [==============================] - 74s 422ms/step - loss: 1.8673 - accuracy: 0.2983 - val_loss: 1.5631 - val_accuracy: 0.3972
# Epoch 3/70
# 169/169 [==============================] - 58s 333ms/step - loss: 1.6592 - accuracy: 0.3657 - val_loss: 1.5931 - val_accuracy: 0.4105
# Epoch 4/70
# 169/169 [==============================] - 58s 336ms/step - loss: 1.5953 - accuracy: 0.3905 - val_loss: 1.4507 - val_accuracy: 0.4291
# Epoch 5/70
# 169/169 [==============================] - 59s 338ms/step - loss: 1.5085 - accuracy: 0.4270 - val_loss: 1.7933 - val_accuracy: 0.3808
# Epoch 6/70
# 169/169 [==============================] - 59s 340ms/step - loss: 1.4642 - accuracy: 0.4415 - val_loss: 1.3391 - val_accuracy: 0.4759
# Epoch 7/70
# 169/169 [==============================] - 60s 347ms/step - loss: 1.4133 - accuracy: 0.4743 - val_loss: 1.3329 - val_accuracy: 0.4900
# Epoch 8/70
# 169/169 [==============================] - 60s 348ms/step - loss: 1.3437 - accuracy: 0.4883 - val_loss: 1.3799 - val_accuracy: 0.4536
# Epoch 9/70
# 169/169 [==============================] - 60s 347ms/step - loss: 1.2737 - accuracy: 0.5263 - val_loss: 1.3849 - val_accuracy: 0.4707
# Epoch 10/70
# 169/169 [==============================] - 63s 364ms/step - loss: 1.2136 - accuracy: 0.5429 - val_loss: 1.2554 - val_accuracy: 0.5145
# Epoch 11/70
# 169/169 [==============================] - 35s 198ms/step - loss: 1.1559 - accuracy: 0.5732 - val_loss: 1.1388 - val_accuracy: 0.5724
# Epoch 12/70
# 169/169 [==============================] - 33s 191ms/step - loss: 1.0507 - accuracy: 0.6016 - val_loss: 1.2364 - val_accuracy: 0.5509
# Epoch 13/70
# 169/169 [==============================] - 33s 191ms/step - loss: 1.0166 - accuracy: 0.6277 - val_loss: 0.9428 - val_accuracy: 0.6592
# Epoch 14/70
# 126/169 [=====================>........] - ETA: 6s - loss: 0.9398 - accuracy: 0.6518

# %% [markdown]
#  #### **Todo:**  Visualize the model results

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()
