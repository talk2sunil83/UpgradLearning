# %% [markdown]
# ## Data Visualisation - Graded Questions

# %% [markdown]
# `Note` - *This stub file doesn't contain the conceptual questions asked on the platform*

# %% [markdown]
# ### I) Marks Analysis
#
# In the **'Marks.csv'** file, you can find the scores obtained by 200 students in 4 subjects of a standardised test. The different columns - `Score A`, `Score B`, `Score C` and `Score D` indicate the score obtained by a particular student in the respective subjects A, B, C and D.
#
#
#
# Load the dataset to your notebook and answer the following questions

# %%
#Load the necessary Libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
print(plt.style.available)
# Out:
# ['Solarize_Light2', '_classic_test_patch', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn', 'seaborn-bright', 'seaborn-colorblind', 'seaborn-dark', 'seaborn-dark-palette', 'seaborn-darkgrid', 'seaborn-deep', 'seaborn-muted', 'seaborn-notebook', 'seaborn-paper', 'seaborn-pastel', 'seaborn-poster', 'seaborn-talk', 'seaborn-ticks', 'seaborn-white', 'seaborn-whitegrid', 'tableau-colorblind10']

# %%
plt.style.use(['dark_background','seaborn-dark', 'seaborn-dark-palette', 'seaborn-darkgrid'])

# %%
#Load the dataset
df1 = pd.read_csv('Marks.csv')

# %%
df1.head()
# Out:
#    Score A  Score B  Score C  Score D
# 0    230.1     37.8     69.2     22.1
# 1     44.5     39.3     45.1     10.4
# 2     17.2     45.9     69.3     12.0
# 3    151.5     41.3     58.5     16.5
# 4    180.8     10.8     58.4     17.9

# %%
df1.isnull().any()
# Out:
# Score A    False
# Score B    False
# Score C    False
# Score D    False
# dtype: bool

# %%
df1.dtypes
# Out:
# Score A    float64
# Score B    float64
# Score C    float64
# Score D    float64
# dtype: object

# %%
df1.describe().T
# Out:
#          count      mean        std  min     25%     50%      75%    max
# Score A  200.0  147.0425  85.854236  0.7  74.375  149.75  218.825  296.4
# Score B  200.0   23.2640  14.846809  0.0   9.975   22.90   36.525   49.6
# Score C  200.0   30.5540  21.778621  0.3  12.750   25.75   45.100  114.0
# Score D  200.0   15.1305   5.283892  1.6  11.000   16.00   19.050   27.0

# %% [markdown]
# **Q1)** Load the dataset and plot a histogram for the `Score A` column by keeping the `number of bins to 6`. Which bin range among the following has the highest frequency?
#
# (`Note` - *The bin ranges mentioned in the options are approximate values for the bin ranges that you'll actually get when you plot the histogram*)
#
#     a)0-50
#     b)50-100
#     c)150-200
#     d)200-250

# %%
#Your code here
df1["Score A"].plot.hist(bins=6)
plt.show()

# %% [markdown]
# **Q2)** Plot a box plot for the column `Score C` and choose the correct option.
#
#     A - The 25th percentile lies between 20 and 40
#     B - The 75th percentile lies between 40 and 60
#     C - The 25th percentile lies between 0 and 20
#     D - Both B and C

# %%
#Your code here
df1['Score C'].plot.box()
plt.show()

# %%
sns.pairplot(data=df1)

# %% [markdown]
# ### II) Superstore Data
#
# In the `superstore.csv` file, you have the details of orders purchased in an American online retail store. Load the dataset, observe and analyse the different columns and answer the following questions.

# %%
#Load the dataset
df2 = pd.read_csv('superstore.csv')

# %%
df2.head()
# Out:
#          Order ID       Ship Mode    Segment Region       Product ID  \
# 0  CA-2016-152156    Second Class   Consumer  South  FUR-BO-10001798
# 1  CA-2016-152156    Second Class   Consumer  South  FUR-CH-10000454
# 2  CA-2016-138688    Second Class  Corporate   West  OFF-LA-10000240
# 3  US-2015-108966  Standard Class   Consumer  South  FUR-TA-10000577
# 4  US-2015-108966  Standard Class   Consumer  South  OFF-ST-10000760
#
#       Sales  Quantity Discount    Profit
# 0  261.9600         2       0%   41.9136
# 1  731.9400         3       0%  219.5820
# 2   14.6200         2       0%    6.8714
# 3  957.5775         5    0.45% -383.0310
# 4   22.3680         2    0.20%    2.5164

# %%
df2.isnull().any()
# Out:
# Order ID      False
# Ship Mode     False
# Segment       False
# Region        False
# Product ID    False
# Sales         False
# Quantity      False
# Discount      False
# Profit        False
# dtype: bool

# %%
df2.dtypes
# Out:
# Order ID       object
# Ship Mode      object
# Segment        object
# Region         object
# Product ID     object
# Sales         float64
# Quantity        int64
# Discount       object
# Profit        float64
# dtype: object

# %%
df2.Discount = df2.Discount.apply(lambda d: float(d.replace("%", "")))

# %%
df2.dtypes
# Out:
# Order ID       object
# Ship Mode      object
# Segment        object
# Region         object
# Product ID     object
# Sales         float64
# Quantity        int64
# Discount      float64
# Profit        float64
# dtype: object

# %% [markdown]
# **Q4)** Plot a pie-chart to find the Ship Mode through which most of the orders are being delivered.
#
#      a)Standard Class
#      b)First Class
#      c)Second Class
#      d)Same Day

# %%
#Your code here
df2['Ship Mode'].value_counts().plot.pie()
plt.show()

# %%
sns.barplot(data = df2, x = 'Segment', y = 'Sales', estimator = np.mean)

# %%
sns.barplot(data = df2, x = 'Segment', y = 'Sales')

# %% [markdown]
# **Q5)** Plot a bar chart comparing the average `Discount` across all the `Regions` and report back the `Region` getting the highest average discount
#
# **Note** - You need to clean the `Discount` column first
#
#     a)Central
#     b)South
#     c)West
#     d)East

# %%
df2.columns
# Out:
# Index(['Order ID', 'Ship Mode', 'Segment', 'Region', 'Product ID', 'Sales',
#        'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
#Your code here
res = df2.groupby('Region')['Discount'].mean().reset_index().sort_values(by='Discount', ascending=False)
sns.barplot(x='Region', y='Discount', hue='Region', data=res)
plt.show()
