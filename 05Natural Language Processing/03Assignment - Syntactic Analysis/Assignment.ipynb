# %% [markdown]
# ### Data Preparation

# %%
# %%
# Importing libraries
from typing import Sequence, Tuple
import nltk
import numpy as np
import pandas as pd
import time
import random
from sklearn.model_selection import train_test_split
from nltk.tokenize import word_tokenize

# %%
# reading the Treebank tagged sentences
wsj = list(nltk.corpus.treebank.tagged_sents(tagset='universal'))

# %%
# Splitting into train and validation
random.seed(1234)
train_set, test_set = train_test_split(wsj, test_size=0.05)

# %%
# Getting list of tagged words
train_tagged_words = [tup for sent in train_set for tup in sent]
len(train_tagged_words)
# Out:
# 95600

# %%
# Getting list of tagged words
validation = [tup for sent in test_set for tup in sent]

# %%
# tokens
tokens = [pair[0] for pair in train_tagged_words]

# %%
# vocabulary
V = set(tokens)

# %%
# number of tags
T = set([pair[1] for pair in train_tagged_words])

# %% [markdown]
#  ### Emission Probabilities

# %%
# computing P(w/t) and storing in T x V matrix
t = len(T)
v = len(V)
w_given_t = np.zeros((t, v))

# %%
# compute word given tag: Emission Probability
def word_given_tag(word:str, tag:str, train_bag:Sequence[Tuple[str, str]]=train_tagged_words)-> Tuple[int, int]:
    """Calculate the count of occurrence of word for given tag and total occurrence of tag

    Args:
        word (str): word
        tag (str): tag
        train_bag (Sequence[Tuple[str, str]], optional): tagged words of training set. Defaults to train_tagged_words.

    Returns:
        Tuple[int, int]: (count of occurrence of word for given tag, total occurrence of tag)
    """    
    tag_list = [pair for pair in train_bag if pair[1] == tag]
    count_tag = len(tag_list)
    w_given_tag_list = [pair[0] for pair in tag_list if pair[0] == word]
    count_w_given_tag = len(w_given_tag_list)

    return (count_w_given_tag, count_tag)

# %% [markdown]
#  ### Transition Probabilities

# %%
# compute tag given tag: tag2(t2) given tag1 (t1), i.e. Transition Probability


def t2_given_t1(t2:str, t1:str, train_bag:Sequence[Tuple[str, str]]=train_tagged_words)-> Tuple[int, int]:
    """ Calculate the count of occurrence of T1-T2 and total occurrence of T1

    Args:
        t2 (str): Second tag
        t1 (str): First tag
        train_bag (Sequence[Tuple[str, str]], optional): tagged words of training set. Defaults to train_tagged_words.

    Returns:
        Tuple[int, int]: (count of occurrence of T1-T2, total occurrence of T1)
    """    
    tags = [pair[1] for pair in train_bag]
    count_t1 = len([t for t in tags if t == t1])
    count_t2_t1 = 0
    for index in range(len(tags)-1):
        if tags[index] == t1 and tags[index+1] == t2:
            count_t2_t1 += 1
    return (count_t2_t1, count_t1)

# %%
# creating t x t transition matrix of tags
# each column is t2, each row is t1
# thus M(i, j) represents P(tj given ti)

tags_matrix = np.zeros((len(T), len(T)), dtype='float32')
for i, t1 in enumerate(list(T)):
    for j, t2 in enumerate(list(T)):
        tags_matrix[i, j] = t2_given_t1(t2, t1)[0]/t2_given_t1(t2, t1)[1]

tags_matrix
# Out:
# array([[9.28686932e-02, 8.92760903e-02, 9.10723880e-02, 2.22202256e-01,
#         4.34704497e-02, 2.69444939e-02, 8.04742202e-02, 5.23621328e-02,
#         5.86491823e-02, 2.33518961e-03, 1.73971623e-01, 6.62834570e-02],
#        [3.52959447e-02, 1.69808388e-01, 9.11488608e-02, 1.09378636e-01,
#         6.57823309e-02, 2.17826396e-01, 2.30393298e-02, 8.22279081e-02,
#         5.50771877e-03, 3.10293995e-02, 1.33503988e-01, 3.54510881e-02],
#        [4.02519740e-02, 8.22122581e-03, 1.76169127e-02, 3.21054876e-01,
#         1.06769167e-01, 3.44864391e-02, 6.27802685e-02, 1.35596842e-02,
#         1.06769160e-03, 1.28123001e-03, 3.24471503e-01, 6.84390366e-02],
#        [2.40493402e-01, 1.46084234e-01, 1.77359313e-01, 2.64761686e-01,
#         1.23713594e-02, 2.90854685e-02, 9.41537134e-03, 1.69330705e-02,
#         4.16028015e-02, 4.39019054e-02, 1.33931832e-02, 4.59820451e-03],
#        [6.45214543e-02, 1.17161712e-02, 7.57425725e-02, 7.01815188e-01,
#         6.58415854e-02, 2.12871283e-02, 2.07920801e-02, 4.95049497e-03,
#         1.71617158e-02, 1.10561056e-02, 4.62046219e-03, 4.95049520e-04],
#        [1.63271800e-01, 2.05124125e-01, 1.45130485e-01, 6.17441125e-02,
#         1.67091023e-02, 7.41565898e-02, 2.86441762e-03, 2.53023561e-02,
#         9.86632705e-03, 1.84118390e-01, 5.55378757e-02, 5.61744124e-02],
#        [1.17229126e-01, 1.89461224e-02, 3.40438113e-02, 3.51095319e-01,
#         3.43398452e-02, 2.10479572e-01, 1.85612783e-01, 2.96033151e-03,
#         1.30254589e-02, 2.75310837e-02, 2.96033151e-03, 1.77619897e-03],
#        [1.37827963e-01, 3.46728653e-01, 1.17901027e-01, 3.28794420e-02,
#         1.27864495e-01, 2.25838590e-02, 3.18830945e-02, 7.80471638e-02,
#         6.97442703e-03, 1.42809702e-02, 6.80836961e-02, 1.49452006e-02],
#        [3.61332707e-02, 1.58610985e-01, 5.34960106e-02, 3.48662585e-01,
#         1.16377287e-01, 8.91600177e-03, 4.08259034e-02, 5.58423288e-02,
#         4.69263265e-04, 5.16189588e-03, 1.18254341e-01, 5.72501160e-02],
#        [4.16120589e-02, 4.01376158e-01, 2.06422023e-02, 2.47051120e-01,
#         8.28964636e-02, 1.34338140e-02, 5.79947568e-02, 9.82961990e-03,
#         2.29357788e-03, 1.96592393e-03, 1.02883354e-01, 1.80209707e-02],
#        [1.70002412e-02, 4.00289372e-02, 9.28381924e-03, 6.37810469e-01,
#         2.04364598e-01, 4.60573919e-02, 2.26669889e-02, 1.26597537e-02,
#         4.82276344e-04, 2.41138172e-04, 5.78731624e-03, 3.61707248e-03],
#        [4.04312685e-02, 4.87100512e-01, 2.19484027e-02, 2.08702356e-01,
#         7.23912194e-02, 9.24143270e-02, 7.70119391e-03, 3.42703126e-02,
#         5.39083546e-03, 1.23219099e-02, 9.24143288e-03, 8.08625296e-03]],
#       dtype=float32)

# %%
# convert the matrix to a df for better readability
tags_df = pd.DataFrame(tags_matrix, columns=list(T), index=list(T))
tags_df
# Out:
#              .      VERB       ADP      NOUN       ADJ         X       NUM  \
# .     0.092869  0.089276  0.091072  0.222202  0.043470  0.026944  0.080474
# VERB  0.035296  0.169808  0.091149  0.109379  0.065782  0.217826  0.023039
# ADP   0.040252  0.008221  0.017617  0.321055  0.106769  0.034486  0.062780
# NOUN  0.240493  0.146084  0.177359  0.264762  0.012371  0.029085  0.009415
# ADJ   0.064521  0.011716  0.075743  0.701815  0.065842  0.021287  0.020792
# X     0.163272  0.205124  0.145130  0.061744  0.016709  0.074157  0.002864
# NUM   0.117229  0.018946  0.034044  0.351095  0.034340  0.210480  0.185613
# ADV   0.137828  0.346729  0.117901  0.032879  0.127864  0.022584  0.031883
# CONJ  0.036133  0.158611  0.053496  0.348663  0.116377  0.008916  0.040826
# PRT   0.041612  0.401376  0.020642  0.247051  0.082896  0.013434  0.057995
# DET   0.017000  0.040029  0.009284  0.637810  0.204365  0.046057  0.022667
# PRON  0.040431  0.487101  0.021948  0.208702  0.072391  0.092414  0.007701
#
#            ADV      CONJ       PRT       DET      PRON
# .     0.052362  0.058649  0.002335  0.173972  0.066283
# VERB  0.082228  0.005508  0.031029  0.133504  0.035451
# ADP   0.013560  0.001068  0.001281  0.324472  0.068439
# NOUN  0.016933  0.041603  0.043902  0.013393  0.004598
# ADJ   0.004950  0.017162  0.011056  0.004620  0.000495
# X     0.025302  0.009866  0.184118  0.055538  0.056174
# NUM   0.002960  0.013025  0.027531  0.002960  0.001776
# ADV   0.078047  0.006974  0.014281  0.068084  0.014945
# CONJ  0.055842  0.000469  0.005162  0.118254  0.057250
# PRT   0.009830  0.002294  0.001966  0.102883  0.018021
# DET   0.012660  0.000482  0.000241  0.005787  0.003617
# PRON  0.034270  0.005391  0.012322  0.009241  0.008086

# %% [markdown]
#  ### Build the vanilla Viterbi based POS tagger

# %%
# Viterbi Heuristic
def Viterbi(words:Sequence[str], train_bag:Sequence[Tuple[str, str]]=train_tagged_words)-> Sequence[Tuple[str, str]]:
    """Vennila Implementation of Viterbi Heuristic


    Args:
        words (Sequence[str]): list of words
        train_bag (Sequence[Tuple[str, str]], optional): tagged words of training set. Defaults to train_tagged_words.

    Returns:
        Sequence[Tuple[str, float]]: words with tag
    """
    state = []
    tags_set = list(set([pair[1] for pair in train_bag]))

    for key, word in enumerate(words):
        # initialise list of probability column for a given observation
        p = []
        for tag in tags_set:
            if key == 0:
                transition_p = tags_df.loc['.', tag]
            else:
                transition_p = tags_df.loc[state[-1], tag]

            # compute emission and state probabilities
            emission_p_parts = word_given_tag(word, tag)
            emission_p = emission_p_parts[0]/emission_p_parts[1]
            state_probability = emission_p * transition_p
            p.append(state_probability)

        p_max = max(p)
        # getting state for which probability is maximum
        state_max = tags_set[p.index(p_max)]
        state.append(state_max)
    return list(zip(words, state))

# %% [markdown]
#  #### Evaluating on Validation Set

# %%
# list of tagged words
validation_run_base = [tup for sent in test_set for tup in sent]

# list of untagged words
validation_tagged_words = [tup[0] for sent in test_set for tup in sent]
print(len(test_set))
print(len(validation_tagged_words))
# Out:
# 196
# 5076

# %%
# tagging the test sentences
start = time.time()
validation_vit_default = Viterbi(validation_tagged_words)
end = time.time()
difference = end-start
print(f"Time taken in seconds: {difference:.2f}")
print(len(validation_tagged_words))
# Out:
# Time taken in seconds: 258.65
# 5076

# %%
# accuracy
check = [i for i, j in zip(validation_vit_default, validation_run_base) if i == j]
accuracy = len(check)/len(validation_vit_default)

print(accuracy)
perf_metric = [("Vennila", accuracy)]
# Out:
# 0.9076044129235619

# %%
incorrect_tagged_cases = [[validation_run_base[i-1], j] for i, j in enumerate(zip(validation_vit_default, validation_run_base)) if j[0] != j[1]]
incorrect_tagged_cases
# Out:
# [[('no', 'DET'), (('downside', '.'), ('downside', 'NOUN'))],
#  [('president', 'NOUN'), (('asserts', '.'), ('asserts', 'VERB'))],
#  [('a', 'DET'), (('tremendous', '.'), ('tremendous', 'ADJ'))],
#  [('aggressive', 'ADJ'), (('participant', '.'), ('participant', 'NOUN'))],
#  [('is', 'VERB'), (('vitally', '.'), ('vitally', 'ADV'))],
#  [('the', 'DET'), (('emotions', '.'), ('emotions', 'NOUN'))],
#  [('the', 'DET'), (('American', 'NOUN'), ('American', 'ADJ'))],
#  [(',', '.'), (('Taizo', '.'), ('Taizo', 'NOUN'))],
#  [('Taizo', 'NOUN'), (('Watanabe', '.'), ('Watanabe', 'NOUN'))],
#  [('$', '.'), (('3.28', '.'), ('3.28', 'NUM'))],
#  [('$', '.'), (('3.16', '.'), ('3.16', 'NUM'))],
#  [("'s", 'PRT'), (('premier', '.'), ('premier', 'ADJ'))],
#  [('is', 'VERB'), (('unworkable', '.'), ('unworkable', 'ADJ'))],
#  [('branch', 'NOUN'), (('unfunded', '.'), ('unfunded', 'ADJ'))],
#  [('could', 'VERB'), (('sign', 'NOUN'), ('sign', 'VERB'))],
#  [('and', 'CONJ'), (('assert', '.'), ('assert', 'VERB'))],
#  [('rider', 'NOUN'), (('restricting', '.'), ('restricting', 'VERB'))],
#  [('a', 'DET'), (('richer', '.'), ('richer', 'ADJ'))],
#  [('the', 'DET'), (('more', 'ADJ'), ('more', 'ADV'))],
#  [('profitable', 'ADJ'), (('pipe', '.'), ('pipe', 'NOUN'))],
#  [('and', 'CONJ'), (('galvanized', '.'), ('galvanized', 'ADJ'))],
#  [('galvanized', 'ADJ'), (('coated', '.'), ('coated', 'VERB'))],
#  [('than', 'ADP'), (('lower-priced', '.'), ('lower-priced', 'ADJ'))],
#  [('lower-priced', 'ADJ'), (('structural', '.'), ('structural', 'ADJ'))],
#  [('needed', 'VERB'), (('*-126', '.'), ('*-126', 'X'))],
#  [('the', 'DET'), (('tumultuous', '.'), ('tumultuous', 'ADJ'))],
#  [('tumultuous', 'ADJ'), (('trading', 'NOUN'), ('trading', 'VERB'))],
#  [('prices', 'NOUN'), (('skidded', '.'), ('skidded', 'VERB'))],
#  [('skidded', 'VERB'), (('as', 'ADP'), ('as', 'ADV'))],
#  [('York', 'NOUN'), (('trading', 'NOUN'), ('trading', 'VERB'))],
#  [('a', 'DET'), (('buildup', '.'), ('buildup', 'NOUN'))],
#  [('production', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('one', 'NUM'), (('that', 'ADP'), ('that', 'DET'))],
#  [('*T*-70', 'X'), (("'s", 'PRT'), ("'s", 'VERB'))],
#  [("'s", 'VERB'), (('captivating', '.'), ('captivating', 'ADJ'))],
#  [('the', 'DET'), (('most', 'ADJ'), ('most', 'ADV'))],
#  [('seem', 'VERB'), (('disagreeable', '.'), ('disagreeable', 'ADJ'))],
#  [('*-1', 'X'), (('asserting', '.'), ('asserting', 'VERB'))],
#  [('a', 'DET'), (('greenmailer', '.'), ('greenmailer', 'NOUN'))],
#  [('to', 'PRT'), (('pressure', 'NOUN'), ('pressure', 'VERB'))],
#  [('electronics', 'NOUN'), (('emerged', '.'), ('emerged', 'VERB'))],
#  [('*-1', 'X'), (('muscling', '.'), ('muscling', 'VERB'))],
#  [('muscling', 'VERB'), (('out', 'ADP'), ('out', 'PRT'))],
#  [('of', 'ADP'), (('5.6', '.'), ('5.6', 'NUM'))],
#  [('goes', 'VERB'), (('ex-dividend', '.'), ('ex-dividend', 'ADJ'))],
#  [('Once', 'ADV'), (('there', 'DET'), ('there', 'ADV'))],
#  [(',', '.'), (('what', 'PRON'), ('what', 'DET'))],
#  [('of', 'ADP'), (('escape', '.'), ('escape', 'NOUN'))],
#  [('*T*-1', 'X'), (('open', 'VERB'), ('open', 'ADJ'))],
#  [('than', 'ADP'), (('drink', 'VERB'), ('drink', 'NOUN'))],
#  [('or', 'CONJ'), (('insanity', '.'), ('insanity', 'NOUN'))],
#  [('far', 'ADV'), (('more', 'ADJ'), ('more', 'ADV'))],
#  [('more', 'ADV'), (('limited', 'ADJ'), ('limited', 'VERB'))],
#  [('limited', 'VERB'), (('applicability', '.'), ('applicability', 'NOUN'))],
#  [(',', '.'), (('disappointed', 'VERB'), ('disappointed', 'ADJ'))],
#  [(',', '.'), (('uncomfortable', '.'), ('uncomfortable', 'ADJ'))],
#  [(',', '.'), (('frankly', '.'), ('frankly', 'ADV'))],
#  [('.', '.'), (('Criminal', 'NOUN'), ('Criminal', 'ADJ'))],
#  [('against', 'ADP'), (('Diceon', '.'), ('Diceon', 'NOUN'))],
#  [('its', 'PRON'), (('Chatsworth', '.'), ('Chatsworth', 'NOUN'))],
#  [('are', 'VERB'), (('insured', '.'), ('insured', 'VERB'))],
#  [('and', 'CONJ'), (('triple-A-rated', '.'), ('triple-A-rated', 'ADJ'))],
#  [('--', '.'), (('and', 'CONJ'), ('and', 'NOUN'))],
#  [('what', 'PRON'), (('*T*-172', '.'), ('*T*-172', 'X'))],
#  [('a', 'DET'), (('Helsinki', '.'), ('Helsinki', 'NOUN'))],
#  [('be', 'VERB'), (('twinned', '.'), ('twinned', 'VERB'))],
#  [('nearly', 'ADV'), (('complete', 'VERB'), ('complete', 'ADJ'))],
#  [('miles', 'NOUN'), (('upstream', '.'), ('upstream', 'ADV'))],
#  [('been', 'VERB'), (('obsessed', '.'), ('obsessed', 'VERB'))],
#  [('*', 'X'), (('refitting', '.'), ('refitting', 'VERB'))],
#  [("'s", 'PRT'), (('Little', 'ADJ'), ('Little', 'NOUN'))],
#  [('In', 'ADP'), (('1986-87', '.'), ('1986-87', 'NUM'))],
#  [('and', 'CONJ'), (('1987-88', '.'), ('1987-88', 'NUM'))],
#  [('bonus', 'NOUN'), (('pay', 'VERB'), ('pay', 'NOUN'))],
#  [('a', 'DET'), (('Sanford', '.'), ('Sanford', 'NOUN'))],
#  [('might', 'VERB'), (('resonate', '.'), ('resonate', 'VERB'))],
#  [('had', 'VERB'), (('as', 'ADP'), ('as', 'ADV'))],
#  [('the', 'DET'), (('camera', '.'), ('camera', 'NOUN'))],
#  [('at', 'ADP'), (('mid-afternoon', '.'), ('mid-afternoon', 'ADJ'))],
#  [('at', 'ADP'), (('260', '.'), ('260', 'NUM'))],
#  [(',', '.'), (('petroleum', '.'), ('petroleum', 'NOUN'))],
#  [('*-1', 'X'), (('Concerned', '.'), ('Concerned', 'VERB'))],
#  [('about', 'ADP'), (('shrinking', '.'), ('shrinking', 'VERB'))],
#  [('shrinking', 'VERB'), (('landfills', '.'), ('landfills', 'NOUN'))],
#  [('in', 'ADP'), (('super-absorbent', '.'), ('super-absorbent', 'ADJ'))],
#  [('super-absorbent', 'ADJ'), (('disposables', '.'), ('disposables', 'NOUN'))],
#  [('traditional', 'ADJ'), (('open-end', '.'), ('open-end', 'ADJ'))],
#  [('these', 'DET'), (('one-country', '.'), ('one-country', 'ADJ'))],
#  [('*-1', 'X'), (('issuing', '.'), ('issuing', 'VERB'))],
#  [('shares', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('an', 'DET'), (('anti-takeover', '.'), ('anti-takeover', 'ADJ'))],
#  [('and', 'CONJ'), (('chief', 'NOUN'), ('chief', 'ADJ'))],
#  [('chief', 'ADJ'), (('executive', 'NOUN'), ('executive', 'ADJ'))],
#  [('improved', 'VERB'), (('operating', 'VERB'), ('operating', 'NOUN'))],
#  [('operating', 'NOUN'), (('efficiencies', '.'), ('efficiencies', 'NOUN'))],
#  [('Market', 'NOUN'), (('Value', '.'), ('Value', 'NOUN'))],
#  [('gained', 'VERB'), (('1.56', '.'), ('1.56', 'NUM'))],
#  [('to', 'PRT'), (('372.14', '.'), ('372.14', 'NUM'))],
#  [('who', 'PRON'), (('*T*-130', '.'), ('*T*-130', 'X'))],
#  [('who', 'PRON'), (('*T*-131', '.'), ('*T*-131', 'X'))],
#  [('.', '.'), (('ECONOMIC', '.'), ('ECONOMIC', 'ADJ'))],
#  [('ECONOMIC', 'ADJ'), (('GROWTH', '.'), ('GROWTH', 'NOUN'))],
#  [('GROWTH', 'NOUN'), (('APPEARS', '.'), ('APPEARS', 'VERB'))],
#  [('leveling', 'VERB'), (('off', 'PRT'), ('off', 'ADP'))],
#  [('the', 'DET'), (('busiest', '.'), ('busiest', 'ADJ'))],
#  [('year', 'NOUN'), (('so', 'ADP'), ('so', 'ADV'))],
#  [('so', 'ADV'), (('far', 'ADV'), ('far', 'ADJ'))],
#  [('volume', 'NOUN'), (('averaged', '.'), ('averaged', 'VERB'))],
#  [('the', 'DET'), (('twindam', '.'), ('twindam', 'NOUN'))],
#  [('becomes', 'VERB'), (('frightened', '.'), ('frightened', 'VERB'))],
#  [('odd', 'ADJ'), (('lotter', '.'), ('lotter', 'NOUN'))],
#  [('Larry', 'NOUN'), (('Zicklin', '.'), ('Zicklin', 'NOUN'))],
#  [('&', 'CONJ'), (('Berman', '.'), ('Berman', 'NOUN'))],
#  [('the', 'DET'), (('YMCA', '.'), ('YMCA', 'NOUN'))],
#  [('the', 'DET'), (('YWCA', '.'), ('YWCA', 'NOUN'))],
#  [('or', 'CONJ'), (('Catholic', '.'), ('Catholic', 'NOUN'))],
#  [('Catholic', 'NOUN'), (('Charities', '.'), ('Charities', 'NOUN'))],
#  [('Charities', 'NOUN'), (('USA', '.'), ('USA', 'NOUN'))],
#  [('organizations', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('*T*-17', 'X'), (('participated', '.'), ('participated', 'VERB'))],
#  [('?', '.'), (('INGERSOLL-RAND', '.'), ('INGERSOLL-RAND', 'NOUN'))],
#  [('-LRB-', '.'), (('Woodcliff', '.'), ('Woodcliff', 'NOUN'))],
#  [('A', 'DET'), (('nickname', '.'), ('nickname', 'NOUN'))],
#  [('have', 'VERB'), (('difficulty', '.'), ('difficulty', 'NOUN'))],
#  [('*-2', 'X'), (('shoring', '.'), ('shoring', 'VERB'))],
#  [('shoring', 'VERB'), (('up', 'ADV'), ('up', 'PRT'))],
#  [('.', '.'), (('Heightened', '.'), ('Heightened', 'ADJ'))],
#  [('in', 'ADP'), (('American', 'NOUN'), ('American', 'ADJ'))],
#  [('business', 'NOUN'), (('parallels', 'NOUN'), ('parallels', 'VERB'))],
#  [('have', 'VERB'), (('reaped', '.'), ('reaped', 'VERB'))],
#  [('The', 'DET'), (('multilevel', '.'), ('multilevel', 'ADJ'))],
#  [('by', 'ADP'), (('Thrall', '.'), ('Thrall', 'NOUN'))],
#  [('held', 'VERB'), (('Duchossois', '.'), ('Duchossois', 'NOUN'))],
#  [(',', '.'), (('Elmhurst', '.'), ('Elmhurst', 'NOUN'))],
#  [('considered', 'VERB'), (('*-77', '.'), ('*-77', 'X'))],
#  [('.', '.'), (('NCNB', '.'), ('NCNB', 'NOUN'))],
#  [('Financial', 'NOUN'), (('Connections', '.'), ('Connections', 'NOUN'))],
#  [('young', 'ADJ'), (('adults', '.'), ('adults', 'NOUN'))],
#  [('crystal', 'NOUN'), (('changes', 'NOUN'), ('changes', 'VERB'))],
#  [('apparently', 'ADV'), (('pins', 'NOUN'), ('pins', 'VERB'))],
#  [('*-3', 'X'), (('lowering', '.'), ('lowering', 'VERB'))],
#  [('Bob', 'NOUN'), (('Lurie', '.'), ('Lurie', 'NOUN'))],
#  [('a', 'DET'), (('small-time', '.'), ('small-time', 'ADJ'))],
#  [('almost', 'ADV'), (('exhausted', '.'), ('exhausted', 'VERB'))],
#  [('the', 'DET'), (('limited', 'ADJ'), ('limited', 'VERB'))],
#  [('the', 'DET'), (("'40s", '.'), ("'40s", 'NUM'))],
#  [('and', 'CONJ'), (("'50s", '.'), ("'50s", 'NUM'))],
#  [('which', 'DET'), (('*T*-165', '.'), ('*T*-165', 'X'))],
#  [('$', '.'), (('3.80', '.'), ('3.80', 'NUM'))],
#  [('The', 'DET'), (('goverment', '.'), ('goverment', 'NOUN'))],
#  [('goverment', 'NOUN'), (('counts', 'NOUN'), ('counts', 'VERB'))],
#  [('Dodge', 'NOUN'), (('counts', 'NOUN'), ('counts', 'VERB'))],
#  [('William', 'NOUN'), (('Dunton', '.'), ('Dunton', 'NOUN'))],
#  [('.', '.'), (('Charities', '.'), ('Charities', 'NOUN'))],
#  [('Charities', 'NOUN'), (('test', 'NOUN'), ('test', 'VERB'))],
#  [('fund', 'NOUN'), (('raising', 'VERB'), ('raising', 'NOUN'))],
#  [('300', 'NUM'), (('million-a-year', '.'), ('million-a-year', 'ADJ'))],
#  [('*T*-2', 'X'), (('Joel', '.'), ('Joel', 'NOUN'))],
#  [('Joel', 'NOUN'), (('Gross', '.'), ('Gross', 'NOUN'))],
#  [('the', 'DET'), (('red', 'ADJ'), ('red', 'NOUN'))],
#  [('the', 'DET'), (('Civil', '.'), ('Civil', 'NOUN'))],
#  [('have', 'VERB'), (('shared', '.'), ('shared', 'VERB'))],
#  [('such', 'ADJ'), (('lawmaking', '.'), ('lawmaking', 'ADJ'))],
#  [('*', 'X'), (('deducting', '.'), ('deducting', 'VERB'))],
#  [('from', 'ADP'), (('gross', '.'), ('gross', 'ADJ'))],
#  [('drove', 'VERB'), (('up', 'ADV'), ('up', 'PRT'))],
#  [("'s", 'PRT'), (('Economic', 'ADJ'), ('Economic', 'NOUN'))],
#  [('drug', 'NOUN'), (('trafficking', '.'), ('trafficking', 'NOUN'))],
#  [('the', 'DET'), (('Andean', '.'), ('Andean', 'ADJ'))],
#  [('the', 'DET'), (('Midwestern', 'ADJ'), ('Midwestern', 'NOUN'))],
#  [('corporate', 'ADJ'), (('indifference', '.'), ('indifference', 'NOUN'))],
#  [("''", '.'), (('Bribe', '.'), ('Bribe', 'NOUN'))],
#  [('by', 'ADP'), (('bribe', '.'), ('bribe', 'NOUN'))],
#  [(',', '.'), (('Matthew', '.'), ('Matthew', 'NOUN'))],
#  [('C.', 'NOUN'), (('Harrison', '.'), ('Harrison', 'NOUN'))],
#  [('the', 'DET'), (('path', '.'), ('path', 'NOUN'))],
#  [('Wedtech', 'NOUN'), (('traveled', '.'), ('traveled', 'VERB'))],
#  [('its', 'PRON'), (('inception', '.'), ('inception', 'NOUN'))],
#  [('small', 'ADJ'), (('manufacturing', 'NOUN'), ('manufacturing', 'VERB'))],
#  [('of', 'ADP'), (('full-fledged', '.'), ('full-fledged', 'ADJ'))],
#  [('producing', 'VERB'), (('vital', '.'), ('vital', 'ADJ'))],
#  [('Dec.', 'NOUN'), (('2-3', '.'), ('2-3', 'NUM'))],
#  [('2-3', 'NUM'), (('tete-a-tete', '.'), ('tete-a-tete', 'NOUN'))],
#  [('PC', 'NOUN'), (('contributors', '.'), ('contributors', 'NOUN'))],
#  [('law', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('who', 'PRON'), (('*T*-126', '.'), ('*T*-126', 'X'))],
#  [('*T*-126', 'X'), (('receives', '.'), ('receives', 'VERB'))],
#  [('receives', 'VERB'), (('more', 'ADV'), ('more', 'ADJ'))],
#  [('to', 'PRT'), (('report', 'NOUN'), ('report', 'VERB'))],
#  [('a', 'DET'), (('document', '.'), ('document', 'NOUN'))],
#  [('as', 'ADP'), (('Form', '.'), ('Form', 'NOUN'))],
#  [('Form', 'NOUN'), (('8300', 'ADJ'), ('8300', 'NUM'))],
#  [('on', 'ADP'), (('newsstands', '.'), ('newsstands', 'NOUN'))],
#  [('for', 'ADP'), (('93,000', '.'), ('93,000', 'NUM'))],
#  [('a', 'DET'), (('pre-approved', '.'), ('pre-approved', 'ADJ'))],
#  [('loan', 'NOUN'), (('up', 'PRT'), ('up', 'ADP'))],
#  [('throws', 'VERB'), (('in', 'ADP'), ('in', 'PRT'))],
#  [('*', 'X'), (('saving', '.'), ('saving', 'VERB'))],
#  [('*U*', 'X'), (('pretax', 'NOUN'), ('pretax', 'ADJ'))],
#  [('citing', 'VERB'), (('extended', 'VERB'), ('extended', 'ADJ'))],
#  [('market', 'NOUN'), (('as', 'ADP'), ('as', 'ADV'))],
#  [('to', 'PRT'), (('switch', 'NOUN'), ('switch', 'VERB'))],
#  [('more', 'ADJ'), (('economical', '.'), ('economical', 'ADJ'))],
#  [('nations', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('higher', 'ADJ'), (('standard', 'ADJ'), ('standard', 'NOUN'))],
#  [('the', 'DET'), (('smooth', '.'), ('smooth', 'ADJ'))],
#  [(',', '.'), (('needle-like', '.'), ('needle-like', 'ADJ'))],
#  [('crocidolite', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('are', 'VERB'), (('classified', '.'), ('classified', 'VERB'))],
#  [('as', 'ADP'), (('amphobiles', '.'), ('amphobiles', 'NOUN'))],
#  [('to', 'PRT'), (('Brooke', '.'), ('Brooke', 'NOUN'))],
#  [('of', 'ADP'), (('pathlogy', '.'), ('pathlogy', 'NOUN'))],
#  [('of', 'ADP'), (('Vermont', '.'), ('Vermont', 'NOUN'))],
#  [('.', '.'), (('Common', 'NOUN'), ('Common', 'ADJ'))],
#  [('trading', 'NOUN'), (('roadblock', '.'), ('roadblock', 'NOUN'))],
#  [('beaten', 'VERB'), (('*-82', '.'), ('*-82', 'X'))],
#  [('seeking', 'VERB'), (('better', 'ADV'), ('better', 'ADJ'))],
#  [('their', 'PRON'), (('high-volume', '.'), ('high-volume', 'ADJ'))],
#  [('or', 'CONJ'), (('overseas', 'ADJ'), ('overseas', 'ADV'))],
#  [('and', 'CONJ'), (('lobbyists', '.'), ('lobbyists', 'NOUN'))],
#  [('lobbyists', 'NOUN'), (('as', 'ADP'), ('as', 'ADV'))],
#  [('of', 'ADP'), (('Orrick', '.'), ('Orrick', 'NOUN'))],
#  [(',', '.'), (('Herrington', '.'), ('Herrington', 'NOUN'))],
#  [('&', 'CONJ'), (('Sutcliffe', '.'), ('Sutcliffe', 'NOUN'))],
#  [('out', 'PRT'), (('much', 'ADJ'), ('much', 'ADV'))],
#  [('much', 'ADV'), (('better', 'ADJ'), ('better', 'ADV'))],
#  [('Yeargin', 'NOUN'), (('distinguished', '.'), ('distinguished', 'VERB'))],
#  [('distinguished', 'VERB'), (('herself', '.'), ('herself', 'PRON'))],
#  [('teaching', 'NOUN'), (('approaches', '.'), ('approaches', 'NOUN'))],
#  [('*-1', 'X'), (('forcing', 'VERB'), ('forcing', 'ADJ'))],
#  [('to', 'PRT'), (('pair', '.'), ('pair', 'VERB'))],
#  [('pair', 'VERB'), (('up', 'ADV'), ('up', 'PRT'))],
#  [('using', 'VERB'), (('college-bowl', '.'), ('college-bowl', 'NOUN'))],
#  [('type', 'NOUN'), (('competitions', '.'), ('competitions', 'NOUN'))],
#  [('The', 'DET'), (('most', 'ADJ'), ('most', 'ADV'))],
#  [('bill', 'NOUN'), (('funding', 'NOUN'), ('funding', 'VERB'))],
#  [('Commerce', 'NOUN'), (('departments', '.'), ('departments', 'NOUN'))],
#  [('construction', 'NOUN'), (('outlays', '.'), ('outlays', 'NOUN'))],
#  [('while', 'ADP'), (('purchasing', 'NOUN'), ('purchasing', 'VERB'))],
#  [('0', 'X'), (('manufacturing', 'VERB'), ('manufacturing', 'NOUN'))],
#  [('.', '.'), (('Stockbrokers', '.'), ('Stockbrokers', 'NOUN'))],
#  [('Stockbrokers', 'NOUN'), (("'", '.'), ("'", 'PRT'))],
#  [('and', 'CONJ'), (('pay', 'VERB'), ('pay', 'NOUN'))],
#  [('has', 'VERB'), (('looked', '.'), ('looked', 'VERB'))],
#  [('private', 'ADJ'), (('Dodger', '.'), ('Dodger', 'NOUN'))],
#  [('brought', 'VERB'), (('more', 'ADV'), ('more', 'ADJ'))],
#  [('took', 'VERB'), (('out', 'PRT'), ('out', 'ADP'))],
#  [('to', 'PRT'), (('monopolize', '.'), ('monopolize', 'VERB'))],
#  [('and', 'CONJ'), (('sew', '.'), ('sew', 'VERB'))],
#  [('it', 'PRON'), (('up', 'ADV'), ('up', 'PRT'))],
#  [('*T*-1', 'X'), (('Chong-sik', '.'), ('Chong-sik', 'NOUN'))],
#  [('of', 'ADP'), (('East', 'NOUN'), ('East', 'ADJ'))],
#  [('0', 'X'), (('that', 'ADP'), ('that', 'DET'))],
#  [('buy', 'VERB'), (('more', 'ADV'), ('more', 'ADJ'))],
#  [('*', 'X'), (('Beginning', '.'), ('Beginning', 'VERB'))],
#  [('in', 'ADP'), (('1980', '.'), ('1980', 'NUM'))],
#  [('the', 'DET'), (('common-law', '.'), ('common-law', 'NOUN'))],
#  [('Salon', 'NOUN'), (('le', '.'), ('le', 'DET'))],
#  [('even', 'ADV'), (('lowering', '.'), ('lowering', 'VERB'))],
#  [('.', '.'), (('Per-share', '.'), ('Per-share', 'ADJ'))],
#  [('Per-share', 'ADJ'), (('net', 'ADJ'), ('net', 'NOUN'))],
#  [('to', 'PRT'), (('7.84', '.'), ('7.84', 'NUM'))],
#  [('from', 'ADP'), (('6.53', '.'), ('6.53', 'NUM'))],
#  [('*-2', 'X'), (('punishing', '.'), ('punishing', 'VERB'))],
#  [('or', 'CONJ'), (('retaliating', '.'), ('retaliating', 'VERB'))],
#  [('the', 'DET'), (('cartoonist', '.'), ('cartoonist', 'NOUN'))],
#  [('*EXP*-3', 'X'), (("'s", 'PRT'), ("'s", 'VERB'))],
#  [('many', 'ADJ'), (('salarymen', '.'), ('salarymen', 'NOUN'))],
#  [('put', 'VERB'), (('in', 'ADP'), ('in', 'PRT'))],
#  [('in', 'PRT'), (('unproductive', '.'), ('unproductive', 'ADJ'))],
#  [('unproductive', 'ADJ'), (('overtime', '.'), ('overtime', 'NOUN'))],
#  [('the', 'DET'), (('sake', '.'), ('sake', 'NOUN'))],
#  [('of', 'ADP'), (('solidarity', '.'), ('solidarity', 'NOUN'))],
#  [(',', '.'), (('that', 'DET'), ('that', 'ADP'))],
#  [('so', 'ADV'), (('hierarchical', '.'), ('hierarchical', 'ADJ'))],
#  [('hierarchical', 'ADJ'), (('that', 'DET'), ('that', 'ADP'))],
#  [('that', 'ADP'), (('only', 'ADJ'), ('only', 'ADV'))],
#  [('the', 'DET'), (('assistant', 'NOUN'), ('assistant', 'ADJ'))],
#  [('and', 'CONJ'), (('that', 'DET'), ('that', 'ADP'))],
#  [('was', 'VERB'), (('chary', '.'), ('chary', 'ADJ'))],
#  [('*-4', 'X'), (('letting', '.'), ('letting', 'VERB'))],
#  [('short-term', 'ADJ'), (('American', 'NOUN'), ('American', 'ADJ'))],
#  [('take', 'VERB'), (('on', 'ADP'), ('on', 'PRT'))],
#  [('*', 'X'), (('letting', '.'), ('letting', 'VERB'))],
#  [('during', 'ADP'), (('wild', '.'), ('wild', 'ADJ'))],
#  [('wild', 'ADJ'), (('stock-price', '.'), ('stock-price', 'NOUN'))],
#  [('electronic', 'ADJ'), (('giveaways', '.'), ('giveaways', 'NOUN'))],
#  [('to', 'PRT'), (('subscribers', '.'), ('subscribers', 'NOUN'))],
#  [('as', 'ADP'), (('telephones', '.'), ('telephones', 'NOUN'))],
#  [('the', 'DET'), (('sensational', '.'), ('sensational', 'ADJ'))],
#  [('the', 'DET'), (('revelations', '.'), ('revelations', 'NOUN'))],
#  [('the', 'DET'), (('breezy', '.'), ('breezy', 'ADJ'))],
#  [(',', '.'), (('easy-to-read', '.'), ('easy-to-read', 'ADJ'))],
#  [('tabloid', 'ADJ'), (('writing', 'VERB'), ('writing', 'NOUN'))],
#  [('of', 'ADP'), (('gripping', '.'), ('gripping', 'ADJ'))],
#  [(',', '.'), (('executes', '.'), ('executes', 'VERB'))],
#  [('an', 'DET'), (('equal-opportunity', '.'), ('equal-opportunity', 'NOUN'))],
#  [('.', '.'), (('Though', '.'), ('Though', 'ADP'))],
#  [('prospective', 'ADJ'), (('acquirers', '.'), ('acquirers', 'NOUN'))],
#  [("n't", 'ADV'), (('noticed', '.'), ('noticed', 'VERB'))],
#  [('Yeargin', 'NOUN'), (('concedes', '.'), ('concedes', 'VERB'))],
#  [('concedes', 'VERB'), (('that', 'DET'), ('that', 'ADP'))],
#  [('went', 'VERB'), (('over', 'ADP'), ('over', 'ADV'))],
#  [(',', '.'), (('highway', '.'), ('highway', 'NOUN'))],
#  [(',', '.'), (('as', 'ADP'), ('as', 'ADV'))],
#  [('as', 'ADV'), (('long', 'ADJ'), ('long', 'ADV'))],
#  [('a', 'DET'), (('crash', 'NOUN'), ('crash', 'ADJ'))],
#  [('the', 'DET'), (('sidewalk', '.'), ('sidewalk', 'NOUN'))],
#  [('the', 'DET'), (('simultaneous', '.'), ('simultaneous', 'ADJ'))],
#  [('.', '.'), (('Average', 'NOUN'), ('Average', 'ADJ'))],
#  [(':', '.'), (('83,206', '.'), ('83,206', 'NUM'))],
#  [('New', 'NOUN'), (('York-based', 'NOUN'), ('York-based', 'ADJ'))],
#  [('a', 'DET'), (('customized', '.'), ('customized', 'VERB'))],
#  [('and', 'CONJ'), (('advertising', 'NOUN'), ('advertising', 'VERB'))],
#  [('*T*-1', 'X'), (('simulates', '.'), ('simulates', 'VERB'))],
#  [('simulates', 'VERB'), (('live', 'VERB'), ('live', 'ADJ'))],
#  [('By', 'ADP'), (('1997', '.'), ('1997', 'NUM'))],
#  [('remaining', 'VERB'), (('uses', 'VERB'), ('uses', 'NOUN'))],
#  [('of', 'ADP'), (('cancer-causing', '.'), ('cancer-causing', 'ADJ'))],
#  [('be', 'VERB'), (('outlawed', '.'), ('outlawed', 'VERB'))],
#  [('Street', 'NOUN'), (('reacted', '.'), ('reacted', 'VERB'))],
#  [('reacted', 'VERB'), (('favorably', '.'), ('favorably', 'ADV'))],
#  [('.', '.'), (('Factories', '.'), ('Factories', 'NOUN'))],
#  [('Factories', 'NOUN'), (('booked', '.'), ('booked', 'VERB'))],
#  [('$', '.'), (('236.74', '.'), ('236.74', 'NUM'))],
#  [('$', '.'), (('236.79', '.'), ('236.79', 'NUM'))],
#  [('just', 'ADV'), (('recouped', '.'), ('recouped', 'VERB'))],
#  [('lost', 'VERB'), (('more', 'ADV'), ('more', 'ADJ'))],
#  [('.', '.'), (('INTER-TEL', '.'), ('INTER-TEL', 'NOUN'))],
#  [('the', 'DET'), (('vacancy', '.'), ('vacancy', 'NOUN'))],
#  [('the', 'DET'), (('more-advanced', '.'), ('more-advanced', 'ADJ'))],
#  [('386', 'NUM'), (('microprocessor', '.'), ('microprocessor', 'NOUN'))],
#  [('four', 'NUM'), (('megabytes', '.'), ('megabytes', 'NOUN'))],
#  [('a', 'DET'), (('100-megabyte', '.'), ('100-megabyte', 'ADJ'))],
#  [('100-megabyte', 'ADJ'), (('hard', 'ADV'), ('hard', 'ADJ'))],
#  [('$', '.'), (('5,699', '.'), ('5,699', 'NUM'))],
#  [('$', '.'), (('6,799', '.'), ('6,799', 'NUM'))],
#  [('.', '.'), (('CERTIFICATES', '.'), ('CERTIFICATES', 'NOUN'))],
#  [('OF', 'ADP'), (('DEPOSIT', '.'), ('DEPOSIT', 'NOUN'))],
#  [(';', '.'), (('8.06', '.'), ('8.06', 'NUM'))],
#  [('their', 'PRON'), (('views', 'VERB'), ('views', 'NOUN'))],
#  [('some', 'DET'), (('flexibility', '.'), ('flexibility', 'NOUN'))],
#  [('active', 'ADJ'), (('55-year-old', '.'), ('55-year-old', 'NOUN'))],
#  [('about', 'ADP'), (('Senior', '.'), ('Senior', 'NOUN'))],
#  [('a', 'DET'), (('75-year-old', '.'), ('75-year-old', 'NUM'))],
#  [('D.', 'NOUN'), (('Carney', '.'), ('Carney', 'NOUN'))],
#  [('lower', 'ADJ'), (('Dutch', 'NOUN'), ('Dutch', 'ADJ'))],
#  [('tax', 'NOUN'), (('outlay', '.'), ('outlay', 'NOUN'))],
#  [("''", '.'), (('Michio', '.'), ('Michio', 'NOUN'))],
#  [('Michio', 'NOUN'), (('Sasaki', '.'), ('Sasaki', 'NOUN'))],
#  [('at', 'ADP'), (('Keidanren', '.'), ('Keidanren', 'NOUN'))],
#  [('Japan', 'NOUN'), (('Federation', '.'), ('Federation', 'NOUN'))],
#  [('of', 'ADP'), (('Economic', 'ADJ'), ('Economic', 'NOUN'))],
#  [('Economic', 'NOUN'), (('Organizations', '.'), ('Organizations', 'NOUN'))],
#  [('or', 'CONJ'), (('fall', 'NOUN'), ('fall', 'VERB'))],
#  [('and', 'CONJ'), (('lobbyists', '.'), ('lobbyists', 'NOUN'))],
#  [('lobbyists', 'NOUN'), (('as', 'ADP'), ('as', 'ADV'))],
#  [('emissions', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('to', 'PRT'), (('acid', 'NOUN'), ('acid', 'ADJ'))],
#  [('be', 'VERB'), (('centralized', '.'), ('centralized', 'VERB'))],
#  [('the', 'DET'), (('subject', 'ADJ'), ('subject', 'NOUN'))],
#  [('U.S.', 'NOUN'), (('direct', 'VERB'), ('direct', 'ADJ'))],
#  [('confidence', 'NOUN'), (('stayed', '.'), ('stayed', 'VERB'))],
#  [('the', 'DET'), (('unsettling', '.'), ('unsettling', 'ADJ'))],
#  [('record', 'NOUN'), (('corn-buying', '.'), ('corn-buying', 'ADJ'))],
#  [('corn-buying', 'ADJ'), (('binge', '.'), ('binge', 'NOUN'))],
#  [('the', 'DET'), (('Soviet', 'ADJ'), ('Soviet', 'NOUN'))],
#  [('serious', 'ADJ'), (('bottlenecks', '.'), ('bottlenecks', 'NOUN'))],
#  [('grain', 'NOUN'), (('pipeline', '.'), ('pipeline', 'NOUN'))],
#  [('Phelan', 'NOUN'), (('angered', '.'), ('angered', 'VERB'))],
#  [('reported', 'VERB'), (('*-131', '.'), ('*-131', 'X'))],
#  [('a', 'DET'), (('knife', '.'), ('knife', 'NOUN'))],
#  [('which', 'DET'), (('flows', 'NOUN'), ('flows', 'VERB'))],
#  [('*T*-1', 'X'), (('much', 'ADV'), ('much', 'ADJ'))],
#  [('corn', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('*-2', 'X'), (('overseas', 'ADJ'), ('overseas', 'ADV'))],
#  [('*T*-1', 'X'), (('Lyle', '.'), ('Lyle', 'NOUN'))],
#  [('Pacific', 'NOUN'), (('Railroad', '.'), ('Railroad', 'NOUN'))],
#  [('of', 'ADP'), (('Waterloo', '.'), ('Waterloo', 'NOUN'))],
#  [('proposal', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('emissions', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('to', 'PRT'), (('acid', 'NOUN'), ('acid', 'ADJ'))],
#  [('indicators', 'NOUN'), (('gauges', '.'), ('gauges', 'VERB'))],
#  [('a', 'DET'), (('worsening', '.'), ('worsening', 'NOUN'))],
#  [('its', 'PRON'), (('Adam', '.'), ('Adam', 'NOUN'))],
#  [('was', 'VERB'), (('plagued', '.'), ('plagued', 'VERB'))],
#  [('with', 'ADP'), (('glitches', '.'), ('glitches', 'NOUN'))],
#  [("'s", 'PRT'), (('fortunes', '.'), ('fortunes', 'NOUN'))],
#  [('*T*-41', 'X'), (("'s", 'PRT'), ("'s", 'VERB'))],
#  [('so', 'ADV'), (('wild', '.'), ('wild', 'ADJ'))],
#  [("'", 'PRT'), (('frenzy', '.'), ('frenzy', 'NOUN'))],
#  [('frenzy', 'NOUN'), (('right', 'NOUN'), ('right', 'ADV'))],
#  [('are', 'VERB'), (('trading', 'NOUN'), ('trading', 'VERB'))],
#  [('their', 'PRON'), (('underlying', 'VERB'), ('underlying', 'ADJ'))],
#  [('.', '.'), (('Some', 'DET'), ('Some', 'ADV'))],
#  [('&', 'CONJ'), (('Berman', '.'), ('Berman', 'NOUN'))],
#  [('for', 'ADP'), (('alleged', 'ADJ'), ('alleged', 'VERB'))],
#  [('John', 'NOUN'), (('Morrell', '.'), ('Morrell', 'NOUN'))],
#  [('a', 'DET'), (('meatpacking', '.'), ('meatpacking', 'NOUN'))],
#  [('United', 'NOUN'), (('Brands', '.'), ('Brands', 'NOUN'))],
#  [('the', 'DET'), (('Constitutional', '.'), ('Constitutional', 'NOUN'))],
#  [('Constitutional', 'NOUN'), (('Convention', '.'), ('Convention', 'NOUN'))],
#  [('of', 'ADP'), (('1787', '.'), ('1787', 'NUM'))],
#  [('of', 'ADP'), (('ceramic', '.'), ('ceramic', 'ADJ'))],
#  [('years', 'NOUN'), (('promise', 'NOUN'), ('promise', 'VERB'))],
#  [('new', 'ADJ'), (('technologies', '.'), ('technologies', 'NOUN'))],
#  [('electrical', 'ADJ'), (('generation', '.'), ('generation', 'NOUN'))],
#  [('figures', 'NOUN'), (('contrast', 'NOUN'), ('contrast', 'VERB'))],
#  [("'s", 'PRT'), (('F.W.', '.'), ('F.W.', 'NOUN'))],
#  [(',', '.'), (('cry', '.'), ('cry', 'VERB'))],
#  [('The', 'DET'), (('tension', '.'), ('tension', 'NOUN'))],
#  [('was', 'VERB'), (('evident', '.'), ('evident', 'ADJ'))],
#  [('final', 'ADJ'), (('banquet', '.'), ('banquet', 'NOUN'))],
#  [('*', 'X'), (('reciting', '.'), ('reciting', 'VERB'))],
#  [('reciting', 'VERB'), (('platitudes', '.'), ('platitudes', 'NOUN'))],
#  [('about', 'ADP'), (('eternal', '.'), ('eternal', 'ADJ'))],
#  [('eternal', 'ADJ'), (('friendship', '.'), ('friendship', 'NOUN'))],
#  [('Have', 'NOUN'), (('Wa', '.'), ('Wa', 'NOUN'))],
#  [('amusing', 'ADJ'), (('chronicle', '.'), ('chronicle', 'NOUN'))],
#  [(',', '.'), (('rationed', '.'), ('rationed', 'VERB'))],
#  [('--', '.'), (('unlike', 'ADP'), ('unlike', 'ADJ'))],
#  [('earlier', 'ADJ'), (('built-from-kit', '.'), ('built-from-kit', 'ADJ'))],
#  [('the', 'DET'), (('Altair', '.'), ('Altair', 'NOUN'))],
#  [(',', '.'), (('Sol', '.'), ('Sol', 'NOUN'))],
#  [('and', 'CONJ'), (('IMSAI', '.'), ('IMSAI', 'NOUN'))],
#  [('had', 'VERB'), (('keyboards', '.'), ('keyboards', 'NOUN'))],
#  [('could', 'VERB'), (('store', 'NOUN'), ('store', 'VERB'))],
#  [('Guaranteed', 'VERB'), (('minimum', 'ADJ'), ('minimum', 'NOUN'))],
#  [('$', '.'), (('3.4', '.'), ('3.4', 'NUM'))],
#  [('-LRB-', '.'), (('NYSE', '.'), ('NYSE', 'NOUN'))],
#  [(';', '.'), (('Symbol', '.'), ('Symbol', 'NOUN'))],
#  [(':', '.'), (('CSV', '.'), ('CSV', 'NOUN'))],
#  [('or', 'CONJ'), (('subtraction', '.'), ('subtraction', 'NOUN'))],
#  [('with', 'ADP'), (('finite', '.'), ('finite', 'ADJ'))],
#  [('$', '.'), (('19.50', '.'), ('19.50', 'NUM'))],
#  [('.', '.'), (('Shorter', '.'), ('Shorter', 'ADJ'))],
#  [('*', 'X'), (('labeling', '.'), ('labeling', 'VERB'))],
#  [('is', 'VERB'), (('incredible', '.'), ('incredible', 'ADJ'))],
#  [('*T*-1', 'X'), (('Walt', '.'), ('Walt', 'NOUN'))],
#  [('Walt', 'NOUN'), (('Haney', '.'), ('Haney', 'NOUN'))],
#  [('to', 'PRT'), (('fly', '.'), ('fly', 'VERB'))],
#  [('his', 'PRON'), (('destination', '.'), ('destination', 'NOUN'))],
#  [('a', 'DET'), (('companion', '.'), ('companion', 'NOUN'))],
#  [('companion', 'NOUN'), (("'s", 'VERB'), ("'s", 'PRT'))],
#  [('they', 'PRON'), (('fly', '.'), ('fly', 'VERB'))],
#  [('$', '.'), (('14.75', '.'), ('14.75', 'NUM'))],
#  [('been', 'VERB'), (('quietly', '.'), ('quietly', 'ADV'))],
#  [('to', 'PRT'), (('tinker', '.'), ('tinker', 'VERB'))],
#  [('and', 'CONJ'), (('amortization', '.'), ('amortization', 'NOUN'))],
#  [('while', 'ADP'), (('index-fund', 'ADJ'), ('index-fund', 'NOUN'))],
#  [('slowly', 'ADV'), (('amass', '.'), ('amass', 'VERB'))],
#  [('.', '.'), (('As', 'ADP'), ('As', 'ADV'))],
#  [('to', 'PRT'), (('double', 'ADJ'), ('double', 'VERB'))],
#  [('is', 'VERB'), (('that', 'ADP'), ('that', 'DET'))],
#  [('*-1', 'X'), (('downright', '.'), ('downright', 'ADV'))],
#  [('downright', 'ADV'), (('thumbing', '.'), ('thumbing', 'VERB'))],
#  [('No', 'DET'), (('dummies', '.'), ('dummies', 'NOUN'))],
#  [('Hills', 'NOUN'), (('lauded', '.'), ('lauded', 'VERB'))],
#  [('book', 'NOUN'), (('pirates', '.'), ('pirates', 'NOUN'))],
#  [('.', '.'), (('Railroad', '.'), ('Railroad', 'NOUN'))],
#  [('are', 'VERB'), (('reaping', '.'), ('reaping', 'VERB'))],
#  [('sudden', 'ADJ'), (('windfall', '.'), ('windfall', 'NOUN'))],
#  [('a', 'DET'), (('unitary', '.'), ('unitary', 'ADJ'))],
#  [('the', 'DET'), (('executive', 'ADJ'), ('executive', 'NOUN'))],
#  [('the', 'DET'), (('Confederation', '.'), ('Confederation', 'NOUN'))],
#  [('the', 'DET'), (('Articles', '.'), ('Articles', 'NOUN'))],
#  [('of', 'ADP'), (('Confederation', '.'), ('Confederation', 'NOUN'))],
#  [('a', 'DET'), (('scenic', '.'), ('scenic', 'ADJ'))],
#  [('a', 'DET'), (('planner', '.'), ('planner', 'NOUN'))]]

# %%
#  Commenting below code to follow the direction "The code that you are submitting should run at our end on the same files without any modification of the code."
#  Read test data file
# file_text = ""
# with open("Test_sentences.txt", "rt") as f:
#     file_text = "".join([line.strip() for line in f.readlines()])

file_text = 'Android is a mobile operating system developed by Google. Android has been the best-selling OS worldwide on smartphones since 2011 and on tablets since 2013. Google and Twitter made a deal in 2015 that gave Google access to Twitter\'s firehose. Twitter is an online news and social networking service on which users post and interact with messages known as tweets. Before entering politics, Donald Trump was a domineering businessman and a television personality. The 2018 FIFA World Cup is the 21st FIFA World Cup, an international football tournament contested once every four years. This is the first World Cup to be held in Eastern Europe and the 11th time that it has been held in Europe. Show me the cheapest round trips from Dallas to Atlanta. I would like to see flights from Denver to Philadelphia. Show me the price of the flights leaving Atlanta at about 3 in the afternoon and arriving in San Francisco. NASA invited social media users to experience the launch of ICESAT-2 Satellite.'

# %%
# Testing
test_words = word_tokenize(file_text)
tagged_seq = Viterbi(test_words)

# %%
print(tagged_seq)
print(difference)
# Out:
# [('Android', '.'), ('is', 'VERB'), ('a', 'DET'), ('mobile', 'ADJ'), ('operating', 'NOUN'), ('system', 'NOUN'), ('developed', 'VERB'), ('by', 'ADP'), ('Google.Android', '.'), ('has', 'VERB'), ('been', 'VERB'), ('the', 'DET'), ('best-selling', 'ADJ'), ('OS', '.'), ('worldwide', '.'), ('on', 'ADP'), ('smartphones', '.'), ('since', 'ADP'), ('2011', '.'), ('and', 'CONJ'), ('on', 'ADP'), ('tablets', 'NOUN'), ('since', 'ADP'), ('2013.Google', '.'), ('and', 'CONJ'), ('Twitter', '.'), ('made', 'VERB'), ('a', 'DET'), ('deal', 'NOUN'), ('in', 'ADP'), ('2015', '.'), ('that', 'DET'), ('gave', 'VERB'), ('Google', '.'), ('access', 'NOUN'), ('to', 'PRT'), ('Twitter', '.'), ("'s", 'VERB'), ('firehose.Twitter', '.'), ('is', 'VERB'), ('an', 'DET'), ('online', '.'), ('news', 'NOUN'), ('and', 'CONJ'), ('social', 'ADJ'), ('networking', 'NOUN'), ('service', 'NOUN'), ('on', 'ADP'), ('which', 'DET'), ('users', 'NOUN'), ('post', 'NOUN'), ('and', 'CONJ'), ('interact', '.'), ('with', 'ADP'), ('messages', '.'), ('known', 'VERB'), ('as', 'ADP'), ('tweets.Before', '.'), ('entering', 'VERB'), ('politics', 'NOUN'), (',', '.'), ('Donald', 'NOUN'), ('Trump', 'NOUN'), ('was', 'VERB'), ('a', 'DET'), ('domineering', '.'), ('businessman', 'NOUN'), ('and', 'CONJ'), ('a', 'DET'), ('television', 'NOUN'), ('personality.The', '.'), ('2018', '.'), ('FIFA', '.'), ('World', 'NOUN'), ('Cup', '.'), ('is', 'VERB'), ('the', 'DET'), ('21st', '.'), ('FIFA', '.'), ('World', 'NOUN'), ('Cup', '.'), (',', '.'), ('an', 'DET'), ('international', 'ADJ'), ('football', 'NOUN'), ('tournament', '.'), ('contested', '.'), ('once', 'ADV'), ('every', 'DET'), ('four', 'NUM'), ('years.This', '.'), ('is', 'VERB'), ('the', 'DET'), ('first', 'ADJ'), ('World', 'NOUN'), ('Cup', '.'), ('to', 'PRT'), ('be', 'VERB'), ('held', 'VERB'), ('in', 'ADP'), ('Eastern', 'NOUN'), ('Europe', 'NOUN'), ('and', 'CONJ'), ('the', 'DET'), ('11th', 'ADJ'), ('time', 'NOUN'), ('that', 'ADP'), ('it', 'PRON'), ('has', 'VERB'), ('been', 'VERB'), ('held', 'VERB'), ('in', 'ADP'), ('Europe.Show', '.'), ('me', 'PRON'), ('the', 'DET'), ('cheapest', 'ADJ'), ('round', 'NOUN'), ('trips', '.'), ('from', 'ADP'), ('Dallas', 'NOUN'), ('to', 'PRT'), ('AtlantaI', '.'), ('would', 'VERB'), ('like', 'ADP'), ('to', 'PRT'), ('see', 'VERB'), ('flights', 'NOUN'), ('from', 'ADP'), ('Denver', 'NOUN'), ('to', 'PRT'), ('Philadelphia.Show', '.'), ('me', 'PRON'), ('the', 'DET'), ('price', 'NOUN'), ('of', 'ADP'), ('the', 'DET'), ('flights', 'NOUN'), ('leaving', 'VERB'), ('Atlanta', 'NOUN'), ('at', 'ADP'), ('about', 'ADP'), ('3', 'NUM'), ('in', 'ADP'), ('the', 'DET'), ('afternoon', 'NOUN'), ('and', 'CONJ'), ('arriving', '.'), ('in', 'ADP'), ('San', 'NOUN'), ('Francisco.NASA', '.'), ('invited', '.'), ('social', 'ADJ'), ('media', 'NOUN'), ('users', 'NOUN'), ('to', 'PRT'), ('experience', 'NOUN'), ('the', 'DET'), ('launch', 'NOUN'), ('of', 'ADP'), ('ICESAT-2', '.'), ('Satellite', '.'), ('.', '.')]
# 258.6486210823059

# %%
# Calculate most common tag in train data set
most_common_tags = pd.Series([p[1] for p in train_tagged_words]).value_counts().sort_values(ascending=False).head()
most_common_tag = list(most_common_tags.index)[0]
print(most_common_tag)
print(most_common_tags)
# Out:
# NOUN
# NOUN    27402
# VERB    12891
# .       11134
# ADP      9366
# DET      8294
# dtype: int64

# %% [markdown]
#  ### Solve the problem of unknown words

# %% [markdown]
#  ### Modification -1: Implementation of Viterbi Heuristic with <u>using most common tag if word is missing from training corpus<u/>

# %%
def Viterbi_Most_Common_Tag(tagged_seq:Sequence[str],most_common_tag:str, train_bag:Sequence[Tuple[str, str]]=train_tagged_words)-> Sequence[Tuple[str, str]]:
    """Implementation of Viterbi Heuristic with most occuring TAG for missing words


    Args:
        tagged_seq (Sequence[str]): list of words
        most_common_tag (str): most common tag
        train_bag (Sequence[Tuple[str, str]], optional): tagged words of training set. Defaults to train_tagged_words.

    Returns:
        Sequence[Tuple[str, float]]: words with tag
    """
    V = list(set([pair[0] for pair in train_bag]))
    words = [pair[0] for pair in tagged_seq]
    tags = [pair[1] for pair in tagged_seq]

    for word_index, word in enumerate(words):
        if word not in V:
            tags[word_index] = most_common_tag

    return list(zip(words, tags))

# %%
validation_most_common_tag = Viterbi_Most_Common_Tag(validation_vit_default, most_common_tag)

# %%
# accuracy
check_most_common_tag = [i for i, j in zip(validation_most_common_tag, validation_run_base) if i == j]
accuracy = len(check_most_common_tag)/len(validation_most_common_tag)
print(accuracy)
perf_metric.append(("With Most Common Tag", accuracy))
# Out:
# 0.9387312844759653

# %%
tagged_most_common_test = Viterbi_Most_Common_Tag(tagged_seq, most_common_tag)
tagged_most_common_test
# Out:
# [('Android', 'NOUN'),
#  ('is', 'VERB'),
#  ('a', 'DET'),
#  ('mobile', 'ADJ'),
#  ('operating', 'NOUN'),
#  ('system', 'NOUN'),
#  ('developed', 'VERB'),
#  ('by', 'ADP'),
#  ('Google.Android', 'NOUN'),
#  ('has', 'VERB'),
#  ('been', 'VERB'),
#  ('the', 'DET'),
#  ('best-selling', 'ADJ'),
#  ('OS', 'NOUN'),
#  ('worldwide', 'NOUN'),
#  ('on', 'ADP'),
#  ('smartphones', 'NOUN'),
#  ('since', 'ADP'),
#  ('2011', 'NOUN'),
#  ('and', 'CONJ'),
#  ('on', 'ADP'),
#  ('tablets', 'NOUN'),
#  ('since', 'ADP'),
#  ('2013.Google', 'NOUN'),
#  ('and', 'CONJ'),
#  ('Twitter', 'NOUN'),
#  ('made', 'VERB'),
#  ('a', 'DET'),
#  ('deal', 'NOUN'),
#  ('in', 'ADP'),
#  ('2015', 'NOUN'),
#  ('that', 'DET'),
#  ('gave', 'VERB'),
#  ('Google', 'NOUN'),
#  ('access', 'NOUN'),
#  ('to', 'PRT'),
#  ('Twitter', 'NOUN'),
#  ("'s", 'VERB'),
#  ('firehose.Twitter', 'NOUN'),
#  ('is', 'VERB'),
#  ('an', 'DET'),
#  ('online', 'NOUN'),
#  ('news', 'NOUN'),
#  ('and', 'CONJ'),
#  ('social', 'ADJ'),
#  ('networking', 'NOUN'),
#  ('service', 'NOUN'),
#  ('on', 'ADP'),
#  ('which', 'DET'),
#  ('users', 'NOUN'),
#  ('post', 'NOUN'),
#  ('and', 'CONJ'),
#  ('interact', 'NOUN'),
#  ('with', 'ADP'),
#  ('messages', 'NOUN'),
#  ('known', 'VERB'),
#  ('as', 'ADP'),
#  ('tweets.Before', 'NOUN'),
#  ('entering', 'VERB'),
#  ('politics', 'NOUN'),
#  (',', '.'),
#  ('Donald', 'NOUN'),
#  ('Trump', 'NOUN'),
#  ('was', 'VERB'),
#  ('a', 'DET'),
#  ('domineering', 'NOUN'),
#  ('businessman', 'NOUN'),
#  ('and', 'CONJ'),
#  ('a', 'DET'),
#  ('television', 'NOUN'),
#  ('personality.The', 'NOUN'),
#  ('2018', 'NOUN'),
#  ('FIFA', 'NOUN'),
#  ('World', 'NOUN'),
#  ('Cup', 'NOUN'),
#  ('is', 'VERB'),
#  ('the', 'DET'),
#  ('21st', 'NOUN'),
#  ('FIFA', 'NOUN'),
#  ('World', 'NOUN'),
#  ('Cup', 'NOUN'),
#  (',', '.'),
#  ('an', 'DET'),
#  ('international', 'ADJ'),
#  ('football', 'NOUN'),
#  ('tournament', 'NOUN'),
#  ('contested', 'NOUN'),
#  ('once', 'ADV'),
#  ('every', 'DET'),
#  ('four', 'NUM'),
#  ('years.This', 'NOUN'),
#  ('is', 'VERB'),
#  ('the', 'DET'),
#  ('first', 'ADJ'),
#  ('World', 'NOUN'),
#  ('Cup', 'NOUN'),
#  ('to', 'PRT'),
#  ('be', 'VERB'),
#  ('held', 'VERB'),
#  ('in', 'ADP'),
#  ('Eastern', 'NOUN'),
#  ('Europe', 'NOUN'),
#  ('and', 'CONJ'),
#  ('the', 'DET'),
#  ('11th', 'ADJ'),
#  ('time', 'NOUN'),
#  ('that', 'ADP'),
#  ('it', 'PRON'),
#  ('has', 'VERB'),
#  ('been', 'VERB'),
#  ('held', 'VERB'),
#  ('in', 'ADP'),
#  ('Europe.Show', 'NOUN'),
#  ('me', 'PRON'),
#  ('the', 'DET'),
#  ('cheapest', 'ADJ'),
#  ('round', 'NOUN'),
#  ('trips', 'NOUN'),
#  ('from', 'ADP'),
#  ('Dallas', 'NOUN'),
#  ('to', 'PRT'),
#  ('AtlantaI', 'NOUN'),
#  ('would', 'VERB'),
#  ('like', 'ADP'),
#  ('to', 'PRT'),
#  ('see', 'VERB'),
#  ('flights', 'NOUN'),
#  ('from', 'ADP'),
#  ('Denver', 'NOUN'),
#  ('to', 'PRT'),
#  ('Philadelphia.Show', 'NOUN'),
#  ('me', 'PRON'),
#  ('the', 'DET'),
#  ('price', 'NOUN'),
#  ('of', 'ADP'),
#  ('the', 'DET'),
#  ('flights', 'NOUN'),
#  ('leaving', 'VERB'),
#  ('Atlanta', 'NOUN'),
#  ('at', 'ADP'),
#  ('about', 'ADP'),
#  ('3', 'NUM'),
#  ('in', 'ADP'),
#  ('the', 'DET'),
#  ('afternoon', 'NOUN'),
#  ('and', 'CONJ'),
#  ('arriving', 'NOUN'),
#  ('in', 'ADP'),
#  ('San', 'NOUN'),
#  ('Francisco.NASA', 'NOUN'),
#  ('invited', 'NOUN'),
#  ('social', 'ADJ'),
#  ('media', 'NOUN'),
#  ('users', 'NOUN'),
#  ('to', 'PRT'),
#  ('experience', 'NOUN'),
#  ('the', 'DET'),
#  ('launch', 'NOUN'),
#  ('of', 'ADP'),
#  ('ICESAT-2', 'NOUN'),
#  ('Satellite', 'NOUN'),
#  ('.', '.')]

# %% [markdown]
#  ### Modification -2: Implementation of Viterbi Heuristic with <u>using only transition probability if word is missing from training corpus</u>

# %%
def Viterbi_Transition(words:Sequence[str], train_bag:Sequence[Tuple[str, str]]=train_tagged_words)-> Sequence[Tuple[str, str]]:
    """Implementation of Viterbi Heuristic with using only transition probability if word is missing from training corpus


    Args:
        tagged_seq (Sequence[str]): list of words
        most_common_tag (str): most common tag
        train_bag (Sequence[Tuple[str, str]], optional): tagged words of training set. Defaults to train_tagged_words.

    Returns:
        Sequence[Tuple[str, float]]: words with tag
    """
    state = []
    all_tags = list(set([pair[1] for pair in train_bag]))

    for word_idx, word in enumerate(words):
        # initialise list of probability column for a given observation
        p = []
        for tag in all_tags:
            if word_idx == 0:
                transition_p = tags_df.loc['.', tag]
            else:
                transition_p = tags_df.loc[state[-1], tag]

            # compute emission and state probabilities
            emission_p_parts = word_given_tag(word, tag)
            emission_p = emission_p_parts[0]/emission_p_parts[1]

            if word in V:
                state_probability = transition_p * emission_p
            else:
                state_probability = transition_p

            p.append(state_probability)

        p_max = max(p)
        # getting state for which probability is maximum
        state_max = all_tags[p.index(p_max)]
        state.append(state_max)
    return list(zip(words, state))

# %%
# tagging the test sentences
validation_transition = Viterbi_Transition(validation_tagged_words)

# %%
# accuracy
check = [i for i, j in zip(validation_transition, validation_run_base) if i == j]
accuracy = len(check)/len(validation_transition)
print(accuracy)
perf_metric.append(("With Transition Prob", accuracy))
# Out:
# 0.9385342789598109

# %%
tagged_transition_test = Viterbi_Transition(test_words)
tagged_transition_test
# Out:
# [('Android', 'NOUN'),
#  ('is', 'VERB'),
#  ('a', 'DET'),
#  ('mobile', 'ADJ'),
#  ('operating', 'NOUN'),
#  ('system', 'NOUN'),
#  ('developed', 'VERB'),
#  ('by', 'ADP'),
#  ('Google.Android', 'DET'),
#  ('has', 'VERB'),
#  ('been', 'VERB'),
#  ('the', 'DET'),
#  ('best-selling', 'ADJ'),
#  ('OS', 'NOUN'),
#  ('worldwide', 'NOUN'),
#  ('on', 'ADP'),
#  ('smartphones', 'DET'),
#  ('since', 'ADP'),
#  ('2011', 'DET'),
#  ('and', 'CONJ'),
#  ('on', 'ADP'),
#  ('tablets', 'NOUN'),
#  ('since', 'ADP'),
#  ('2013.Google', 'DET'),
#  ('and', 'CONJ'),
#  ('Twitter', 'NOUN'),
#  ('made', 'VERB'),
#  ('a', 'DET'),
#  ('deal', 'NOUN'),
#  ('in', 'ADP'),
#  ('2015', 'DET'),
#  ('that', 'ADP'),
#  ('gave', 'VERB'),
#  ('Google', 'X'),
#  ('access', 'NOUN'),
#  ('to', 'PRT'),
#  ('Twitter', 'VERB'),
#  ("'s", 'PRT'),
#  ('firehose.Twitter', 'VERB'),
#  ('is', 'VERB'),
#  ('an', 'DET'),
#  ('online', 'NOUN'),
#  ('news', 'NOUN'),
#  ('and', 'CONJ'),
#  ('social', 'ADJ'),
#  ('networking', 'NOUN'),
#  ('service', 'NOUN'),
#  ('on', 'ADP'),
#  ('which', 'DET'),
#  ('users', 'NOUN'),
#  ('post', 'NOUN'),
#  ('and', 'CONJ'),
#  ('interact', 'NOUN'),
#  ('with', 'ADP'),
#  ('messages', 'DET'),
#  ('known', 'VERB'),
#  ('as', 'ADP'),
#  ('tweets.Before', 'DET'),
#  ('entering', 'VERB'),
#  ('politics', 'NOUN'),
#  (',', '.'),
#  ('Donald', 'NOUN'),
#  ('Trump', 'NOUN'),
#  ('was', 'VERB'),
#  ('a', 'DET'),
#  ('domineering', 'NOUN'),
#  ('businessman', 'NOUN'),
#  ('and', 'CONJ'),
#  ('a', 'DET'),
#  ('television', 'NOUN'),
#  ('personality.The', 'NOUN'),
#  ('2018', 'NOUN'),
#  ('FIFA', 'NOUN'),
#  ('World', 'NOUN'),
#  ('Cup', 'NOUN'),
#  ('is', 'VERB'),
#  ('the', 'DET'),
#  ('21st', 'NOUN'),
#  ('FIFA', 'NOUN'),
#  ('World', 'NOUN'),
#  ('Cup', 'NOUN'),
#  (',', '.'),
#  ('an', 'DET'),
#  ('international', 'ADJ'),
#  ('football', 'NOUN'),
#  ('tournament', 'NOUN'),
#  ('contested', 'NOUN'),
#  ('once', 'ADV'),
#  ('every', 'DET'),
#  ('four', 'NUM'),
#  ('years.This', 'NOUN'),
#  ('is', 'VERB'),
#  ('the', 'DET'),
#  ('first', 'ADJ'),
#  ('World', 'NOUN'),
#  ('Cup', 'NOUN'),
#  ('to', 'PRT'),
#  ('be', 'VERB'),
#  ('held', 'VERB'),
#  ('in', 'ADP'),
#  ('Eastern', 'NOUN'),
#  ('Europe', 'NOUN'),
#  ('and', 'CONJ'),
#  ('the', 'DET'),
#  ('11th', 'ADJ'),
#  ('time', 'NOUN'),
#  ('that', 'ADP'),
#  ('it', 'PRON'),
#  ('has', 'VERB'),
#  ('been', 'VERB'),
#  ('held', 'VERB'),
#  ('in', 'ADP'),
#  ('Europe.Show', 'DET'),
#  ('me', 'PRON'),
#  ('the', 'DET'),
#  ('cheapest', 'ADJ'),
#  ('round', 'NOUN'),
#  ('trips', 'NOUN'),
#  ('from', 'ADP'),
#  ('Dallas', 'NOUN'),
#  ('to', 'PRT'),
#  ('AtlantaI', 'VERB'),
#  ('would', 'VERB'),
#  ('like', 'ADP'),
#  ('to', 'PRT'),
#  ('see', 'VERB'),
#  ('flights', 'NOUN'),
#  ('from', 'ADP'),
#  ('Denver', 'NOUN'),
#  ('to', 'PRT'),
#  ('Philadelphia.Show', 'VERB'),
#  ('me', 'PRON'),
#  ('the', 'DET'),
#  ('price', 'NOUN'),
#  ('of', 'ADP'),
#  ('the', 'DET'),
#  ('flights', 'NOUN'),
#  ('leaving', 'VERB'),
#  ('Atlanta', 'NOUN'),
#  ('at', 'ADP'),
#  ('about', 'ADP'),
#  ('3', 'NUM'),
#  ('in', 'ADP'),
#  ('the', 'DET'),
#  ('afternoon', 'NOUN'),
#  ('and', 'CONJ'),
#  ('arriving', 'NOUN'),
#  ('in', 'ADP'),
#  ('San', 'NOUN'),
#  ('Francisco.NASA', 'NOUN'),
#  ('invited', 'NOUN'),
#  ('social', 'ADJ'),
#  ('media', 'NOUN'),
#  ('users', 'NOUN'),
#  ('to', 'PRT'),
#  ('experience', 'NOUN'),
#  ('the', 'DET'),
#  ('launch', 'NOUN'),
#  ('of', 'ADP'),
#  ('ICESAT-2', 'DET'),
#  ('Satellite', 'NOUN'),
#  ('.', '.')]

# %%
pd.DataFrame(perf_metric, columns=["Algorithm", "Accuracy"]).sort_values(by="Accuracy", ascending=False)
# Out:
#               Algorithm  Accuracy
# 1  With Most Common Tag  0.938731
# 2  With Transition Prob  0.938534
# 0               Vennila  0.907604

# %% [markdown]
# ##  As we can see that <u>Viterbi With Most Common Tag</u> has out performed others
#
# ### We could use few more methods like:
#    - Tag Chaining
#    - Rule Based
